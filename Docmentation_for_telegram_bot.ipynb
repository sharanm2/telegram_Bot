# %% [markdown]
# # Uses of Bots
#
#     Get customized notifications and news
#
#     Accept Payment
#
#     create custom tools
#
#     Bulid social services

# %% [markdown]
# # How to Create a New Bot for Telegram
#
#
# ->Open Telegram messenger, sign in to your account or create a new one.
#
# <B>Step 1</B> . Enter @Botfather in the search tab and choose this bot.
#
# Official Telegram bots have a blue checkmark beside their name.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Step 2. Choose or type the /newbot command and send it.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <B>Step 3</B>.
#
#  Choose a name for your bot — your subscribers will see it in the conversation. And choose a username for your bot — the bot can be found by its username in searches. The username must be unique and end with the word “bot.”
#
#
#  ![image.png](attachment:image.png)
#
#
#
#  After you choose a suitable name for your bot — the bot is created. You will receive a message with a link to your bot t.me/<bot_username>, recommendations to set up a profile picture, description, and a list of commands to manage your new bot.
#
# To connect a bot to SendPulse you need a token. Copy your token value and find more information about connecting your bot to SendPulse in the last section of this article.
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# After the above step
#
# ->open your vs code and create a venv
#
# -> pip install python-telegram-bot
#
# -> get a pull from this repository https://github.com/sharanm2/telegram_Bot.git
